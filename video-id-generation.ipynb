# %%
import json
import urllib.request
import string
import random, time
count = 50
# API_KEY = 'AIzaSyBJ7-Vj16CX7RQ4fT-fGtAXG5KX_K1CO_E'
# API_KEY = 'AIzaSyAm9kBVxO-2bjWGI9FqFkkSKgOTH5fCF1A'
#API_KEY = 'AIzaSyDIYMDKxm5bmcSDpNazhSwM4NTlTNKgRsc'
with open("key.txt", 'r') as f:
    API_KEY = f.readline()
    print(API_KEY)
ids = set()
for i in range (60):
    randomQuery = ''.join(random.choice(string.ascii_uppercase + string.digits) for _ in range(3))

    urlData = "https://www.googleapis.com/youtube/v3/search?key={}&maxResults={}&part=snippet&type=video&q={}".format(API_KEY,count,randomQuery)

    webURL = urllib.request.urlopen(urlData)
    data = webURL.read()
    encoding = webURL.info().get_content_charset('utf-8')
    results = json.loads(data.decode(encoding))
    time.sleep(8)
    for data in results['items']:
        videoId = (data['id']['videoId'])
        #store your ids
        ids.add(videoId)
    print('Videos added, current size: ', len(ids))

with open("video-ids2.csv", "w+") as f:
    for id in ids:
        f.write(id + ",")
# Out:
# AIzaSyA9Z3-3ixz8YjsuF_ldNnUEw22nVFxy0P0
# Videos added, current size:  50
# Videos added, current size:  100
# Videos added, current size:  150
# Videos added, current size:  200
# Videos added, current size:  250
# Videos added, current size:  300
# Videos added, current size:  350
# Videos added, current size:  400
# Videos added, current size:  450
# Videos added, current size:  500
# Videos added, current size:  550
# Videos added, current size:  600
# Videos added, current size:  650
# Videos added, current size:  700
# Videos added, current size:  750
# Videos added, current size:  800
# Videos added, current size:  850
# Videos added, current size:  900
# Videos added, current size:  950
# Videos added, current size:  1000
# Videos added, current size:  1050
# Videos added, current size:  1100
# Videos added, current size:  1150
# Videos added, current size:  1200
# Videos added, current size:  1250
# Videos added, current size:  1300
# Videos added, current size:  1350
# Videos added, current size:  1400
# Videos added, current size:  1450
# Videos added, current size:  1500
# Videos added, current size:  1550
# Videos added, current size:  1600
# Videos added, current size:  1650
# Videos added, current size:  1700
# Videos added, current size:  1750
# Videos added, current size:  1800
# Videos added, current size:  1850
# Videos added, current size:  1900
# Videos added, current size:  1950
# Videos added, current size:  2000
# Videos added, current size:  2050
# Videos added, current size:  2100
# Videos added, current size:  2150
# Videos added, current size:  2200
# Videos added, current size:  2250
# Videos added, current size:  2300
# Videos added, current size:  2350
# Videos added, current size:  2400
# Videos added, current size:  2450
# Videos added, current size:  2500
# Videos added, current size:  2550
# Videos added, current size:  2600
# Videos added, current size:  2650
# Videos added, current size:  2700
# Videos added, current size:  2750
# Videos added, current size:  2800
# Videos added, current size:  2850
# Videos added, current size:  2900
# Videos added, current size:  2950
# Videos added, current size:  3000
